# %% [markdown]
# <a href="https://colab.research.google.com/github/Nsimaar99/Nsima-Project/blob/master/My_nx_(1)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## AI Programming with Python Nanodegree: Image Classifier Project
#   - Do not make changes to the first 2 code cells, they are being used for setting up the `flowers` dataset and `cat_to_name.json`. Start writing code from third code cell onwards.
#   - To use this notebook: `File > Save a copy in Drive`

# %% [markdown]
# ### Code Explanation:
#
# - **Setting Up Flower Dataset:**
#   - `data_dir = './flowers'`: Defines the directory path for the flower dataset.
#   - `FLOWERS_DIR = Path(data_dir)`: Uses `Path` from `pathlib` for handling PosixPath.
#
# - **Downloading and Extracting Dataset:**
#   - `if not FLOWERS_DIR.is_dir()`: Checks if the dataset directory exists.
#     - `FLOWERS_DIR.mkdir(parents=True, exist_ok=True)`: Creates the directory if not present.
#   - `TARBALL = FLOWERS_DIR / "flower_data.tar.gz"`: Defines the tarball path.
#   - Downloads and extracts the dataset if not already present:
#     - `request = requests.get(...)`: Downloads the 'flower_data.tar.gz' file.
#     - `with open(TARBALL, "wb") as file_ref`: Writes the downloaded content to the tarball.
#     - `with tarfile.open(TARBALL, "r") as tar_ref`: Extracts the tarball contents to the dataset directory.
#
# - **Cleaning Up:**
#   - `os.remove(TARBALL)`: Deletes the downloaded tarball to save space.
#
# - **Status Messages:**
#   - Prints informative messages about the directory creation, download, extraction, and cleanup.

# %%
# imports
import os
import requests
from pathlib import Path
import tarfile

# defining dataset directory
data_dir = './flowers'

# using pathlib.Path for handling PosixPath
FLOWERS_DIR = Path(data_dir)

# downloading and setting up data if not already present
if not FLOWERS_DIR.is_dir():
    # creating directory
    FLOWERS_DIR.mkdir(parents=True, exist_ok=True)
    print(f"[INFO] Directory created: ./{FLOWERS_DIR}")

    print() # for readability

    # tarball path
    TARBALL = FLOWERS_DIR / "flower_data.tar.gz"

    # downloading and writing the tarball to './flowers' directory
    print(f"[INFO] Downloading the file 'flower_data.tar.gz' to ./{FLOWERS_DIR}")
    request = requests.get('https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz')
    with open(TARBALL, "wb") as file_ref:
        file_ref.write(request.content)
        print(f"[INFO] 'flower_data.tar.gz' saved to ./{FLOWERS_DIR}")

    print() # for readability

    # extracting the downloaded tarball
    print(f"[INFO] Extracting the downloaded tarball to ./{FLOWERS_DIR}")
    with tarfile.open(TARBALL, "r") as tar_ref:
        tar_ref.extractall(FLOWERS_DIR)
        print(f"[INFO] 'flower_data.tar.gz' extracted successfully to ./{FLOWERS_DIR}")

    print() # for readability

    # using os.remove to delete the downloaded tarball
    print("[INFO] Deleting the tarball to save space.")
    os.remove(TARBALL)
else:
    print(f"[INFO] Dataset already setup at ./{FLOWERS_DIR}")
# Out:
# [INFO] Directory created: ./flowers
#
# [INFO] Downloading the file 'flower_data.tar.gz' to ./flowers
# [INFO] 'flower_data.tar.gz' saved to ./flowers
#
# [INFO] Extracting the downloaded tarball to ./flowers
# [INFO] 'flower_data.tar.gz' extracted successfully to ./flowers
#
# [INFO] Deleting the tarball to save space.

# %% [markdown]
# ### Code Explanation:
#
# - **Creating a JSON File for Flower Categories:**
#   - `data`: Defines a dictionary containing numerical keys and corresponding flower names.
#   - `with open('cat_to_name.json', 'w') as file`: Opens the file 'cat_to_name.json' for writing.
#   - `json.dump(data, file)`: Writes the dictionary data to the JSON file.
#
# - **Interpreting the Output:**
#   - The code creates a JSON file named 'cat_to_name.json' that serves as a mapping between numerical keys and flower names. This mapping can be useful for associating numerical labels with human-readable names in machine learning tasks.

# %%
import json

data = {
    "21": "fire lily", "3": "canterbury bells", "45": "bolero deep blue", "1": "pink primrose", "34": "mexican aster",
    "27": "prince of wales feathers", "7": "moon orchid", "16": "globe-flower", "25": "grape hyacinth", "26": "corn poppy",
    "79": "toad lily", "39": "siam tulip", "24": "red ginger", "67": "spring crocus", "35": "alpine sea holly",
    "32": "garden phlox", "10": "globe thistle", "6": "tiger lily", "93": "ball moss", "33": "love in the mist",
    "9": "monkshood", "102": "blackberry lily", "14": "spear thistle", "19": "balloon flower", "100": "blanket flower",
    "13": "king protea", "49": "oxeye daisy", "15": "yellow iris", "61": "cautleya spicata", "31": "carnation",
    "64": "silverbush", "68": "bearded iris", "63": "black-eyed susan", "69": "windflower", "62": "japanese anemone",
    "20": "giant white arum lily", "38": "great masterwort", "4": "sweet pea", "86": "tree mallow",
    "101": "trumpet creeper", "42": "daffodil", "22": "pincushion flower", "2": "hard-leaved pocket orchid",
    "54": "sunflower", "66": "osteospermum", "70": "tree poppy", "85": "desert-rose", "99": "bromelia", "87": "magnolia",
    "5": "english marigold", "92": "bee balm", "28": "stemless gentian", "97": "mallow", "57": "gaura",
    "40": "lenten rose", "47": "marigold", "59": "orange dahlia", "48": "buttercup", "55": "pelargonium",
    "36": "ruby-lipped cattleya", "91": "hippeastrum", "29": "artichoke", "71": "gazania", "90": "canna lily",
    "18": "peruvian lily", "98": "mexican petunia", "8": "bird of paradise", "30": "sweet william",
    "17": "purple coneflower", "52": "wild pansy", "84": "columbine", "12": "colt's foot", "11": "snapdragon",
    "96": "camellia", "23": "fritillary", "50": "common dandelion", "44": "poinsettia", "53": "primula",
    "72": "azalea", "65": "californian poppy", "80": "anthurium", "76": "morning glory", "37": "cape flower",
    "56": "bishop of llandaff", "60": "pink-yellow dahlia", "82": "clematis", "58": "geranium", "75": "thorn apple",
    "41": "barbeton daisy", "95": "bougainvillea", "43": "sword lily", "83": "hibiscus", "78": "lotus lotus",
    "88": "cyclamen", "94": "foxglove", "81": "frangipani", "74": "rose", "89": "watercress", "73": "water lily",
    "46": "wallflower", "77": "passion flower", "51": "petunia"
}

with open('cat_to_name.json', 'w') as file:
    json.dump(data, file)

# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms, models
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import json
from torch.utils.data import DataLoader, TensorDataset
import torch.nn.functional as F
from collections import OrderedDict
import pandas as pd
import os
import seaborn as sns

# %%
import glob
import os

# Define the root directory where the images are located
root_dir = '/content/flowers/test/'

# Use glob to recursively find all images in the root directory and subdirectories
image_paths = glob.glob(os.path.join(root_dir, '**/*.jpg'), recursive=True)

# Print all the image paths
for image_path in image_paths:
    print(image_path)
# Out:
# /content/flowers/test/9/image_06410.jpg
# /content/flowers/test/9/image_06413.jpg
# /content/flowers/test/56/image_02821.jpg
# /content/flowers/test/56/image_02808.jpg
# /content/flowers/test/56/image_02779.jpg
# /content/flowers/test/56/image_02844.jpg
# /content/flowers/test/56/image_02785.jpg
# /content/flowers/test/56/image_02841.jpg
# /content/flowers/test/56/image_02772.jpg
# /content/flowers/test/56/image_02825.jpg
# /content/flowers/test/62/image_08177.jpg
# /content/flowers/test/62/image_07276.jpg
# /content/flowers/test/62/image_07269.jpg
# /content/flowers/test/62/image_08172.jpg
# /content/flowers/test/42/image_05711.jpg
# /content/flowers/test/42/image_05731.jpg
# /content/flowers/test/42/image_05730.jpg
# /content/flowers/test/42/image_05696.jpg
# /content/flowers/test/22/image_05391.jpg
# /content/flowers/test/22/image_05362.jpg
# /content/flowers/test/22/image_05366.jpg
# /content/flowers/test/22/image_05360.jpg
# /content/flowers/test/86/image_02912.jpg
# /content/flowers/test/86/image_02865.jpg
# /content/flowers/test/86/image_02873.jpg
# /content/flowers/test/86/image_02893.jpg
# /content/flowers/test/86/image_02910.jpg
# /content/flowers/test/32/image_05595.jpg
# /content/flowers/test/32/image_05591.jpg
# /content/flowers/test/32/image_05592.jpg
# /content/flowers/test/32/image_05610.jpg
# /content/flowers/test/32/image_05614.jpg
# /content/flowers/test/32/image_05602.jpg
# /content/flowers/test/54/image_05402.jpg
# /content/flowers/test/54/image_05430.jpg
# /content/flowers/test/54/image_05440.jpg
# /content/flowers/test/54/image_05413.jpg
# /content/flowers/test/3/image_06634.jpg
# /content/flowers/test/3/image_06641.jpg
# /content/flowers/test/73/image_00319.jpg
# /content/flowers/test/73/image_00369.jpg
# /content/flowers/test/73/image_00282.jpg
# /content/flowers/test/73/image_00400.jpg
# /content/flowers/test/73/image_00349.jpg
# /content/flowers/test/73/image_00365.jpg
# /content/flowers/test/73/image_00337.jpg
# /content/flowers/test/73/image_00320.jpg
# /content/flowers/test/73/image_00258.jpg
# /content/flowers/test/73/image_00353.jpg
# /content/flowers/test/73/image_00389.jpg
# /content/flowers/test/73/image_00387.jpg
# /content/flowers/test/73/image_00294.jpg
# /content/flowers/test/73/image_00284.jpg
# /content/flowers/test/73/image_00345.jpg
# /content/flowers/test/73/image_00324.jpg
# /content/flowers/test/73/image_00277.jpg
# /content/flowers/test/73/image_00330.jpg
# /content/flowers/test/73/image_00401.jpg
# /content/flowers/test/73/image_00303.jpg
# /content/flowers/test/73/image_00288.jpg
# /content/flowers/test/73/image_00260.jpg
# /content/flowers/test/73/image_00394.jpg
# /content/flowers/test/73/image_00445.jpg
# /content/flowers/test/73/image_00335.jpg
# /content/flowers/test/73/image_00426.jpg
# /content/flowers/test/73/image_00291.jpg
# /content/flowers/test/73/image_00409.jpg
# /content/flowers/test/55/image_04731.jpg
# /content/flowers/test/55/image_04740.jpg
# /content/flowers/test/55/image_04707.jpg
# /content/flowers/test/55/image_04701.jpg
# /content/flowers/test/55/image_04742.jpg
# /content/flowers/test/55/image_04747.jpg
# /content/flowers/test/55/image_04733.jpg
# /content/flowers/test/15/image_06351.jpg
# /content/flowers/test/15/image_06360.jpg
# /content/flowers/test/15/image_06369.jpg
# /content/flowers/test/15/image_06374.jpg
# /content/flowers/test/60/image_02971.jpg
# /content/flowers/test/60/image_02987.jpg
# /content/flowers/test/60/image_02932.jpg
# /content/flowers/test/60/image_03000.jpg
# /content/flowers/test/60/image_02933.jpg
# /content/flowers/test/60/image_03026.jpg
# /content/flowers/test/60/image_02958.jpg
# /content/flowers/test/60/image_02977.jpg
# /content/flowers/test/60/image_03008.jpg
# /content/flowers/test/60/image_02978.jpg
# /content/flowers/test/80/image_02051.jpg
# /content/flowers/test/80/image_02023.jpg
# /content/flowers/test/80/image_01996.jpg
# /content/flowers/test/80/image_02055.jpg
# /content/flowers/test/80/image_01983.jpg
# /content/flowers/test/80/image_02020.jpg
# /content/flowers/test/80/image_01993.jpg
# /content/flowers/test/80/image_01990.jpg
# /content/flowers/test/80/image_02062.jpg
# /content/flowers/test/80/image_02041.jpg
# /content/flowers/test/80/image_02049.jpg
# /content/flowers/test/27/image_06864.jpg
# /content/flowers/test/27/image_06871.jpg
# /content/flowers/test/27/image_06887.jpg
# /content/flowers/test/38/image_05806.jpg
# /content/flowers/test/38/image_05799.jpg
# /content/flowers/test/38/image_05812.jpg
# /content/flowers/test/38/image_05833.jpg
# /content/flowers/test/38/image_05825.jpg
# /content/flowers/test/38/image_05824.jpg
# /content/flowers/test/38/image_05796.jpg
# /content/flowers/test/38/image_05797.jpg
# /content/flowers/test/49/image_06215.jpg
# /content/flowers/test/49/image_06202.jpg
# /content/flowers/test/49/image_06213.jpg
# /content/flowers/test/79/image_06708.jpg
# /content/flowers/test/79/image_06726.jpg
# /content/flowers/test/79/image_06720.jpg
# /content/flowers/test/36/image_04382.jpg
# /content/flowers/test/36/image_04400.jpg
# /content/flowers/test/36/image_04364.jpg
# /content/flowers/test/36/image_04334.jpg
# /content/flowers/test/36/image_04373.jpg
# /content/flowers/test/36/image_04344.jpg
# /content/flowers/test/36/image_04392.jpg
# /content/flowers/test/52/image_04160.jpg
# /content/flowers/test/52/image_04221.jpg
# /content/flowers/test/52/image_04168.jpg
# /content/flowers/test/52/image_04169.jpg
# /content/flowers/test/52/image_04240.jpg
# /content/flowers/test/52/image_04200.jpg
# /content/flowers/test/52/image_04167.jpg
# /content/flowers/test/52/image_04181.jpg
# /content/flowers/test/8/image_03347.jpg
# /content/flowers/test/8/image_03364.jpg
# /content/flowers/test/8/image_03357.jpg
# /content/flowers/test/8/image_03319.jpg
# /content/flowers/test/8/image_03299.jpg
# /content/flowers/test/8/image_03359.jpg
# /content/flowers/test/8/image_03314.jpg
# /content/flowers/test/8/image_03295.jpg
# /content/flowers/test/8/image_03291.jpg
# /content/flowers/test/8/image_03320.jpg
# /content/flowers/test/59/image_05039.jpg
# /content/flowers/test/59/image_05020.jpg
# /content/flowers/test/59/image_05067.jpg
# /content/flowers/test/59/image_05064.jpg
# /content/flowers/test/59/image_05038.jpg
# /content/flowers/test/59/image_05033.jpg
# /content/flowers/test/59/image_05052.jpg
# /content/flowers/test/95/image_07508.jpg
# /content/flowers/test/95/image_07470.jpg
# /content/flowers/test/95/image_07505.jpg
# /content/flowers/test/95/image_07487.jpg
# /content/flowers/test/95/image_07514.jpg
# /content/flowers/test/95/image_07472.jpg
# /content/flowers/test/95/image_07550.jpg
# /content/flowers/test/95/image_07468.jpg
# /content/flowers/test/95/image_07584.jpg
# /content/flowers/test/95/image_07536.jpg
# /content/flowers/test/95/image_07561.jpg
# /content/flowers/test/95/image_07551.jpg
# /content/flowers/test/95/image_07573.jpg
# /content/flowers/test/95/image_07519.jpg
# /content/flowers/test/28/image_05214.jpg
# /content/flowers/test/28/image_05277.jpg
# /content/flowers/test/28/image_05230.jpg
# /content/flowers/test/28/image_05253.jpg
# /content/flowers/test/28/image_05242.jpg
# /content/flowers/test/28/image_05270.jpg
# /content/flowers/test/68/image_05927.jpg
# /content/flowers/test/68/image_05903.jpg
# /content/flowers/test/68/image_05956.jpg
# /content/flowers/test/43/image_02412.jpg
# /content/flowers/test/43/image_02433.jpg
# /content/flowers/test/43/image_02349.jpg
# /content/flowers/test/43/image_02400.jpg
# /content/flowers/test/43/image_02426.jpg
# /content/flowers/test/43/image_02370.jpg
# /content/flowers/test/43/image_02369.jpg
# /content/flowers/test/43/image_02329.jpg
# /content/flowers/test/43/image_02335.jpg
# /content/flowers/test/43/image_02435.jpg
# /content/flowers/test/43/image_02394.jpg
# /content/flowers/test/43/image_02386.jpg
# /content/flowers/test/43/image_02365.jpg
# /content/flowers/test/43/image_02431.jpg
# /content/flowers/test/43/image_02346.jpg
# /content/flowers/test/43/image_02371.jpg
# /content/flowers/test/17/image_03911.jpg
# /content/flowers/test/17/image_03846.jpg
# /content/flowers/test/17/image_03855.jpg
# /content/flowers/test/17/image_03893.jpg
# /content/flowers/test/17/image_03906.jpg
# /content/flowers/test/17/image_03872.jpg
# /content/flowers/test/17/image_03830.jpg
# /content/flowers/test/17/image_03861.jpg
# /content/flowers/test/17/image_03864.jpg
# /content/flowers/test/37/image_03741.jpg
# /content/flowers/test/37/image_03821.jpg
# /content/flowers/test/37/image_03807.jpg
# /content/flowers/test/37/image_03734.jpg
# /content/flowers/test/37/image_03789.jpg
# /content/flowers/test/37/image_03815.jpg
# /content/flowers/test/37/image_03783.jpg
# /content/flowers/test/37/image_03811.jpg
# /content/flowers/test/82/image_01653.jpg
# /content/flowers/test/82/image_01618.jpg
# /content/flowers/test/82/image_01594.jpg
# /content/flowers/test/82/image_01650.jpg
# /content/flowers/test/82/image_01679.jpg
# /content/flowers/test/82/image_01609.jpg
# /content/flowers/test/82/image_01666.jpg
# /content/flowers/test/82/image_01685.jpg
# /content/flowers/test/82/image_01686.jpg
# /content/flowers/test/82/image_01599.jpg
# /content/flowers/test/82/image_01672.jpg
# /content/flowers/test/82/image_01603.jpg
# /content/flowers/test/82/image_01598.jpg
# /content/flowers/test/82/image_01610.jpg
# /content/flowers/test/82/image_01661.jpg
# /content/flowers/test/82/image_01662.jpg
# /content/flowers/test/82/image_01614.jpg
# /content/flowers/test/83/image_01774.jpg
# /content/flowers/test/83/image_01770.jpg
# /content/flowers/test/83/image_01737.jpg
# /content/flowers/test/83/image_01759.jpg
# /content/flowers/test/83/image_01810.jpg
# /content/flowers/test/83/image_01742.jpg
# /content/flowers/test/83/image_01755.jpg
# /content/flowers/test/83/image_01748.jpg
# /content/flowers/test/83/image_01809.jpg
# /content/flowers/test/83/image_01789.jpg
# /content/flowers/test/83/image_01805.jpg
# /content/flowers/test/83/image_01818.jpg
# /content/flowers/test/83/image_01735.jpg
# /content/flowers/test/83/image_01777.jpg
# /content/flowers/test/89/image_00779.jpg
# /content/flowers/test/89/image_00610.jpg
# /content/flowers/test/89/image_00617.jpg
# /content/flowers/test/89/image_00699.jpg
# /content/flowers/test/89/image_00745.jpg
# /content/flowers/test/89/image_00654.jpg
# /content/flowers/test/89/image_00726.jpg
# /content/flowers/test/89/image_00740.jpg
# /content/flowers/test/89/image_00755.jpg
# /content/flowers/test/89/image_00708.jpg
# /content/flowers/test/89/image_00634.jpg
# /content/flowers/test/89/image_00756.jpg
# /content/flowers/test/89/image_00724.jpg
# /content/flowers/test/89/image_00676.jpg
# /content/flowers/test/89/image_00645.jpg
# /content/flowers/test/48/image_04671.jpg
# /content/flowers/test/48/image_04667.jpg
# /content/flowers/test/48/image_04663.jpg
# /content/flowers/test/48/image_04627.jpg
# /content/flowers/test/48/image_04665.jpg
# /content/flowers/test/21/image_06805.jpg
# /content/flowers/test/21/image_06807.jpg
# /content/flowers/test/18/image_04272.jpg
# /content/flowers/test/18/image_04322.jpg
# /content/flowers/test/18/image_04254.jpg
# /content/flowers/test/18/image_04292.jpg
# /content/flowers/test/18/image_04277.jpg
# /content/flowers/test/18/image_04256.jpg
# /content/flowers/test/31/image_06903.jpg
# /content/flowers/test/31/image_08070.jpg
# /content/flowers/test/20/image_04912.jpg
# /content/flowers/test/20/image_04938.jpg
# /content/flowers/test/20/image_04910.jpg
# /content/flowers/test/69/image_05994.jpg
# /content/flowers/test/69/image_05959.jpg
# /content/flowers/test/69/image_05971.jpg
# /content/flowers/test/23/image_03414.jpg
# /content/flowers/test/23/image_03454.jpg
# /content/flowers/test/23/image_03382.jpg
# /content/flowers/test/23/image_03442.jpg
# /content/flowers/test/23/image_03390.jpg
# /content/flowers/test/23/image_03409.jpg
# /content/flowers/test/23/image_03440.jpg
# /content/flowers/test/2/image_05133.jpg
# /content/flowers/test/2/image_05100.jpg
# /content/flowers/test/2/image_05109.jpg
# /content/flowers/test/2/image_05107.jpg
# /content/flowers/test/2/image_05125.jpg
# /content/flowers/test/65/image_03252.jpg
# /content/flowers/test/65/image_03211.jpg
# /content/flowers/test/65/image_03197.jpg
# /content/flowers/test/65/image_03243.jpg
# /content/flowers/test/65/image_03258.jpg
# /content/flowers/test/65/image_03188.jpg
# /content/flowers/test/65/image_03269.jpg
# /content/flowers/test/93/image_06021.jpg
# /content/flowers/test/93/image_06033.jpg
# /content/flowers/test/93/image_06017.jpg
# /content/flowers/test/93/image_06031.jpg
# /content/flowers/test/93/image_06037.jpg
# /content/flowers/test/93/image_06014.jpg
# /content/flowers/test/50/image_06297.jpg
# /content/flowers/test/50/image_06318.jpg
# /content/flowers/test/50/image_06319.jpg
# /content/flowers/test/50/image_06546.jpg
# /content/flowers/test/50/image_06547.jpg
# /content/flowers/test/50/image_06321.jpg
# /content/flowers/test/50/image_06541.jpg
# /content/flowers/test/50/image_06320.jpg
# /content/flowers/test/74/image_01249.jpg
# /content/flowers/test/74/image_01213.jpg
# /content/flowers/test/74/image_01173.jpg
# /content/flowers/test/74/image_01151.jpg
# /content/flowers/test/74/image_01209.jpg
# /content/flowers/test/74/image_01254.jpg
# /content/flowers/test/74/image_01191.jpg
# /content/flowers/test/74/image_01312.jpg
# /content/flowers/test/74/image_01276.jpg
# /content/flowers/test/74/image_01305.jpg
# /content/flowers/test/74/image_01200.jpg
# /content/flowers/test/74/image_01165.jpg
# /content/flowers/test/74/image_01256.jpg
# /content/flowers/test/74/image_01307.jpg
# /content/flowers/test/5/image_05186.jpg
# /content/flowers/test/5/image_05166.jpg
# /content/flowers/test/5/image_05169.jpg
# /content/flowers/test/5/image_05159.jpg
# /content/flowers/test/63/image_05875.jpg
# /content/flowers/test/63/image_05878.jpg
# /content/flowers/test/63/image_05890.jpg
# /content/flowers/test/63/image_05882.jpg
# /content/flowers/test/24/image_06849.jpg
# /content/flowers/test/24/image_06815.jpg
# /content/flowers/test/7/image_08104.jpg
# /content/flowers/test/7/image_07218.jpg
# /content/flowers/test/7/image_07219.jpg
# /content/flowers/test/7/image_07215.jpg
# /content/flowers/test/7/image_08099.jpg
# /content/flowers/test/7/image_07211.jpg
# /content/flowers/test/45/image_07139.jpg
# /content/flowers/test/45/image_07142.jpg
# /content/flowers/test/45/image_07140.jpg
# /content/flowers/test/88/image_00594.jpg
# /content/flowers/test/88/image_00540.jpg
# /content/flowers/test/88/image_00474.jpg
# /content/flowers/test/88/image_00563.jpg
# /content/flowers/test/88/image_00584.jpg
# /content/flowers/test/88/image_00582.jpg
# /content/flowers/test/88/image_00526.jpg
# /content/flowers/test/88/image_00467.jpg
# /content/flowers/test/88/image_00482.jpg
# /content/flowers/test/88/image_00457.jpg
# /content/flowers/test/88/image_00477.jpg
# /content/flowers/test/88/image_00520.jpg
# /content/flowers/test/88/image_00551.jpg
# /content/flowers/test/84/image_02576.jpg
# /content/flowers/test/84/image_02583.jpg
# /content/flowers/test/84/image_02557.jpg
# /content/flowers/test/84/image_02615.jpg
# /content/flowers/test/84/image_02586.jpg
# /content/flowers/test/84/image_02563.jpg
# /content/flowers/test/84/image_02568.jpg
# /content/flowers/test/84/image_02581.jpg
# /content/flowers/test/84/image_02572.jpg
# /content/flowers/test/84/image_02613.jpg
# /content/flowers/test/77/image_00092.jpg
# /content/flowers/test/77/image_00177.jpg
# /content/flowers/test/77/image_00191.jpg
# /content/flowers/test/77/image_00251.jpg
# /content/flowers/test/77/image_00203.jpg
# /content/flowers/test/77/image_00060.jpg
# /content/flowers/test/77/image_00050.jpg
# /content/flowers/test/77/image_00222.jpg
# /content/flowers/test/77/image_00212.jpg
# /content/flowers/test/77/image_00187.jpg
# /content/flowers/test/77/image_00202.jpg
# /content/flowers/test/77/image_00065.jpg
# /content/flowers/test/77/image_00239.jpg
# /content/flowers/test/77/image_00204.jpg
# /content/flowers/test/77/image_00025.jpg
# /content/flowers/test/77/image_00005.jpg
# /content/flowers/test/77/image_00114.jpg
# /content/flowers/test/77/image_00099.jpg
# /content/flowers/test/77/image_00006.jpg
# /content/flowers/test/77/image_00176.jpg
# /content/flowers/test/77/image_00116.jpg
# /content/flowers/test/77/image_00248.jpg
# /content/flowers/test/77/image_00029.jpg
# /content/flowers/test/77/image_00024.jpg
# /content/flowers/test/77/image_00132.jpg
# /content/flowers/test/101/image_07949.jpg
# /content/flowers/test/101/image_07983.jpg
# /content/flowers/test/101/image_07988.jpg
# /content/flowers/test/101/image_07952.jpg
# /content/flowers/test/87/image_05488.jpg
# /content/flowers/test/87/image_05462.jpg
# /content/flowers/test/87/image_05466.jpg
# /content/flowers/test/87/image_05485.jpg
# /content/flowers/test/87/image_05469.jpg
# /content/flowers/test/87/image_05493.jpg
# /content/flowers/test/97/image_07709.jpg
# /content/flowers/test/97/image_07719.jpg
# /content/flowers/test/97/image_07737.jpg
# /content/flowers/test/97/image_07708.jpg
# /content/flowers/test/97/image_07696.jpg
# /content/flowers/test/91/image_04851.jpg
# /content/flowers/test/91/image_04860.jpg
# /content/flowers/test/91/image_08061.jpg
# /content/flowers/test/91/image_04883.jpg
# /content/flowers/test/91/image_04870.jpg
# /content/flowers/test/91/image_04856.jpg
# /content/flowers/test/91/image_04890.jpg
# /content/flowers/test/91/image_04875.jpg
# /content/flowers/test/4/image_05678.jpg
# /content/flowers/test/4/image_05658.jpg
# /content/flowers/test/4/image_05637.jpg
# /content/flowers/test/4/image_05653.jpg
# /content/flowers/test/4/image_05640.jpg
# /content/flowers/test/4/image_05636.jpg
# /content/flowers/test/61/image_06249.jpg
# /content/flowers/test/61/image_06248.jpg
# /content/flowers/test/61/image_06284.jpg
# /content/flowers/test/61/image_06290.jpg
# /content/flowers/test/61/image_06271.jpg
# /content/flowers/test/61/image_06266.jpg
# /content/flowers/test/61/image_06251.jpg
# /content/flowers/test/61/image_06279.jpg
# /content/flowers/test/51/image_01468.jpg
# /content/flowers/test/51/image_03980.jpg
# /content/flowers/test/51/image_03985.jpg
# /content/flowers/test/51/image_01335.jpg
# /content/flowers/test/51/image_01370.jpg
# /content/flowers/test/51/image_01388.jpg
# /content/flowers/test/51/image_03986.jpg
# /content/flowers/test/51/image_01316.jpg
# /content/flowers/test/51/image_01406.jpg
# /content/flowers/test/51/image_01340.jpg
# /content/flowers/test/51/image_01362.jpg
# /content/flowers/test/51/image_01407.jpg
# /content/flowers/test/51/image_03960.jpg
# /content/flowers/test/51/image_03954.jpg
# /content/flowers/test/51/image_03939.jpg
# /content/flowers/test/51/image_03989.jpg
# /content/flowers/test/51/image_01474.jpg
# /content/flowers/test/51/image_01314.jpg
# /content/flowers/test/51/image_01457.jpg
# /content/flowers/test/51/image_03973.jpg
# /content/flowers/test/51/image_01328.jpg
# /content/flowers/test/51/image_03968.jpg
# /content/flowers/test/51/image_03926.jpg
# /content/flowers/test/51/image_03984.jpg
# /content/flowers/test/34/image_06929.jpg
# /content/flowers/test/34/image_06933.jpg
# /content/flowers/test/34/image_06941.jpg
# /content/flowers/test/34/image_06954.jpg
# /content/flowers/test/34/image_06961.jpg
# /content/flowers/test/14/image_06083.jpg
# /content/flowers/test/14/image_06091.jpg
# /content/flowers/test/14/image_06052.jpg
# /content/flowers/test/71/image_04515.jpg
# /content/flowers/test/71/image_04557.jpg
# /content/flowers/test/71/image_04488.jpg
# /content/flowers/test/71/image_04524.jpg
# /content/flowers/test/71/image_04512.jpg
# /content/flowers/test/71/image_04514.jpg
# /content/flowers/test/71/image_04519.jpg
# /content/flowers/test/71/image_04555.jpg
# /content/flowers/test/71/image_04482.jpg
# /content/flowers/test/33/image_06478.jpg
# /content/flowers/test/33/image_06470.jpg
# /content/flowers/test/33/image_06460.jpg
# /content/flowers/test/33/image_06457.jpg
# /content/flowers/test/33/image_06454.jpg
# /content/flowers/test/33/image_06456.jpg
# /content/flowers/test/33/image_06486.jpg
# /content/flowers/test/33/image_06479.jpg
# /content/flowers/test/94/image_07333.jpg
# /content/flowers/test/94/image_07358.jpg
# /content/flowers/test/94/image_07352.jpg
# /content/flowers/test/94/image_07415.jpg
# /content/flowers/test/94/image_07357.jpg
# /content/flowers/test/94/image_07327.jpg
# /content/flowers/test/94/image_07395.jpg
# /content/flowers/test/94/image_07388.jpg
# /content/flowers/test/94/image_07434.jpg
# /content/flowers/test/94/image_07308.jpg
# /content/flowers/test/94/image_07399.jpg
# /content/flowers/test/94/image_07436.jpg
# /content/flowers/test/94/image_07361.jpg
# /content/flowers/test/94/image_07346.jpg
# /content/flowers/test/94/image_07370.jpg
# /content/flowers/test/94/image_07400.jpg
# /content/flowers/test/90/image_04473.jpg
# /content/flowers/test/90/image_04420.jpg
# /content/flowers/test/90/image_04468.jpg
# /content/flowers/test/90/image_04430.jpg
# /content/flowers/test/90/image_04405.jpg
# /content/flowers/test/90/image_04459.jpg
# /content/flowers/test/90/image_04431.jpg
# /content/flowers/test/90/image_04426.jpg
# /content/flowers/test/90/image_04428.jpg
# /content/flowers/test/90/image_04407.jpg
# /content/flowers/test/90/image_04458.jpg
# /content/flowers/test/90/image_04469.jpg
# /content/flowers/test/90/image_04417.jpg
# /content/flowers/test/90/image_04432.jpg
# /content/flowers/test/16/image_06657.jpg
# /content/flowers/test/16/image_06670.jpg
# /content/flowers/test/16/image_06673.jpg
# /content/flowers/test/1/image_06743.jpg
# /content/flowers/test/1/image_06752.jpg
# /content/flowers/test/1/image_06760.jpg
# /content/flowers/test/1/image_06754.jpg
# /content/flowers/test/1/image_06764.jpg
# /content/flowers/test/57/image_08133.jpg
# /content/flowers/test/57/image_07242.jpg
# /content/flowers/test/57/image_07250.jpg
# /content/flowers/test/57/image_07266.jpg
# /content/flowers/test/57/image_07234.jpg
# /content/flowers/test/57/image_07241.jpg
# /content/flowers/test/57/image_08134.jpg
# /content/flowers/test/57/image_08129.jpg
# /content/flowers/test/57/image_08127.jpg
# /content/flowers/test/57/image_08144.jpg
# /content/flowers/test/57/image_07267.jpg
# /content/flowers/test/75/image_02144.jpg
# /content/flowers/test/75/image_02157.jpg
# /content/flowers/test/75/image_02111.jpg
# /content/flowers/test/75/image_02167.jpg
# /content/flowers/test/75/image_02119.jpg
# /content/flowers/test/75/image_02115.jpg
# /content/flowers/test/75/image_02075.jpg
# /content/flowers/test/75/image_02078.jpg
# /content/flowers/test/75/image_02188.jpg
# /content/flowers/test/75/image_02085.jpg
# /content/flowers/test/75/image_02154.jpg
# /content/flowers/test/75/image_02088.jpg
# /content/flowers/test/75/image_02135.jpg
# /content/flowers/test/29/image_04112.jpg
# /content/flowers/test/29/image_04142.jpg
# /content/flowers/test/29/image_04090.jpg
# /content/flowers/test/29/image_04083.jpg
# /content/flowers/test/29/image_04095.jpg
# /content/flowers/test/29/image_04145.jpg
# /content/flowers/test/29/image_04137.jpg
# /content/flowers/test/29/image_04146.jpg
# /content/flowers/test/29/image_04124.jpg
# /content/flowers/test/67/image_07079.jpg
# /content/flowers/test/67/image_07080.jpg
# /content/flowers/test/67/image_07056.jpg
# /content/flowers/test/67/image_07082.jpg
# /content/flowers/test/25/image_06582.jpg
# /content/flowers/test/25/image_06611.jpg
# /content/flowers/test/25/image_06583.jpg
# /content/flowers/test/25/image_06593.jpg
# /content/flowers/test/25/image_06580.jpg
# /content/flowers/test/72/image_03603.jpg
# /content/flowers/test/72/image_03633.jpg
# /content/flowers/test/72/image_03625.jpg
# /content/flowers/test/72/image_03575.jpg
# /content/flowers/test/72/image_03635.jpg
# /content/flowers/test/72/image_03593.jpg
# /content/flowers/test/72/image_03628.jpg
# /content/flowers/test/72/image_03613.jpg
# /content/flowers/test/72/image_03547.jpg
# /content/flowers/test/72/image_03624.jpg
# /content/flowers/test/72/image_03599.jpg
# /content/flowers/test/26/image_06497.jpg
# /content/flowers/test/26/image_06498.jpg
# /content/flowers/test/26/image_06514.jpg
# /content/flowers/test/26/image_06526.jpg
# /content/flowers/test/26/image_06500.jpg
# /content/flowers/test/6/image_07182.jpg
# /content/flowers/test/6/image_07191.jpg
# /content/flowers/test/6/image_07181.jpg
# /content/flowers/test/6/image_07198.jpg
# /content/flowers/test/6/image_08108.jpg
# /content/flowers/test/6/image_07185.jpg
# /content/flowers/test/6/image_07199.jpg
# /content/flowers/test/6/image_07173.jpg
# /content/flowers/test/6/image_08106.jpg
# /content/flowers/test/35/image_06986.jpg
# /content/flowers/test/35/image_06992.jpg
# /content/flowers/test/35/image_08088.jpg
# /content/flowers/test/35/image_08084.jpg
# /content/flowers/test/35/image_07006.jpg
# /content/flowers/test/35/image_06984.jpg
# /content/flowers/test/100/image_07902.jpg
# /content/flowers/test/100/image_07926.jpg
# /content/flowers/test/100/image_07938.jpg
# /content/flowers/test/100/image_07896.jpg
# /content/flowers/test/100/image_07897.jpg
# /content/flowers/test/100/image_07939.jpg
# /content/flowers/test/100/image_07936.jpg
# /content/flowers/test/100/image_07899.jpg
# /content/flowers/test/85/image_04814.jpg
# /content/flowers/test/85/image_04819.jpg
# /content/flowers/test/85/image_04808.jpg
# /content/flowers/test/85/image_04786.jpg
# /content/flowers/test/85/image_04825.jpg
# /content/flowers/test/85/image_04805.jpg
# /content/flowers/test/85/image_04801.jpg
# /content/flowers/test/85/image_04797.jpg
# /content/flowers/test/85/image_04810.jpg
# /content/flowers/test/85/image_04806.jpg
# /content/flowers/test/10/image_07117.jpg
# /content/flowers/test/10/image_07090.jpg
# /content/flowers/test/10/image_07104.jpg
# /content/flowers/test/58/image_02663.jpg
# /content/flowers/test/58/image_02738.jpg
# /content/flowers/test/58/image_02695.jpg
# /content/flowers/test/58/image_02677.jpg
# /content/flowers/test/58/image_02722.jpg
# /content/flowers/test/58/image_02694.jpg
# /content/flowers/test/58/image_02687.jpg
# /content/flowers/test/58/image_02719.jpg
# /content/flowers/test/58/image_02721.jpg
# /content/flowers/test/58/image_02743.jpg
# /content/flowers/test/58/image_02672.jpg
# /content/flowers/test/58/image_02737.jpg
# /content/flowers/test/58/image_02752.jpg
# /content/flowers/test/58/image_02681.jpg
# /content/flowers/test/64/image_06099.jpg
# /content/flowers/test/64/image_06134.jpg
# /content/flowers/test/64/image_06138.jpg
# /content/flowers/test/64/image_06130.jpg
# /content/flowers/test/64/image_06104.jpg
# /content/flowers/test/98/image_07753.jpg
# /content/flowers/test/98/image_07777.jpg
# /content/flowers/test/98/image_07787.jpg
# /content/flowers/test/98/image_07758.jpg
# /content/flowers/test/39/image_07035.jpg
# /content/flowers/test/39/image_07016.jpg
# /content/flowers/test/39/image_07010.jpg
# /content/flowers/test/39/image_07018.jpg
# /content/flowers/test/39/image_07043.jpg
# /content/flowers/test/70/image_05308.jpg
# /content/flowers/test/70/image_05324.jpg
# /content/flowers/test/70/image_05330.jpg
# /content/flowers/test/70/image_05331.jpg
# /content/flowers/test/40/image_04563.jpg
# /content/flowers/test/40/image_04609.jpg
# /content/flowers/test/40/image_04587.jpg
# /content/flowers/test/40/image_04582.jpg
# /content/flowers/test/40/image_04573.jpg
# /content/flowers/test/40/image_04586.jpg
# /content/flowers/test/40/image_04568.jpg
# /content/flowers/test/40/image_04588.jpg
# /content/flowers/test/96/image_07597.jpg
# /content/flowers/test/96/image_07676.jpg
# /content/flowers/test/96/image_07622.jpg
# /content/flowers/test/96/image_07683.jpg
# /content/flowers/test/96/image_07672.jpg
# /content/flowers/test/96/image_07646.jpg
# /content/flowers/test/96/image_07606.jpg
# /content/flowers/test/96/image_07668.jpg
# /content/flowers/test/96/image_07596.jpg
# /content/flowers/test/102/image_08023.jpg
# /content/flowers/test/102/image_08015.jpg
# /content/flowers/test/102/image_08012.jpg
# /content/flowers/test/102/image_08042.jpg
# /content/flowers/test/102/image_08030.jpg
# /content/flowers/test/102/image_08004.jpg
# /content/flowers/test/66/image_05549.jpg
# /content/flowers/test/66/image_05537.jpg
# /content/flowers/test/66/image_05582.jpg
# /content/flowers/test/66/image_05562.jpg
# /content/flowers/test/11/image_03177.jpg
# /content/flowers/test/11/image_03176.jpg
# /content/flowers/test/11/image_03098.jpg
# /content/flowers/test/11/image_03151.jpg
# /content/flowers/test/11/image_03147.jpg
# /content/flowers/test/11/image_03141.jpg
# /content/flowers/test/11/image_03165.jpg
# /content/flowers/test/11/image_03115.jpg
# /content/flowers/test/11/image_03130.jpg
# /content/flowers/test/44/image_01502.jpg
# /content/flowers/test/44/image_01578.jpg
# /content/flowers/test/44/image_01548.jpg
# /content/flowers/test/44/image_01530.jpg
# /content/flowers/test/44/image_01515.jpg
# /content/flowers/test/44/image_01560.jpg
# /content/flowers/test/44/image_01527.jpg
# /content/flowers/test/44/image_01518.jpg
# /content/flowers/test/44/image_01516.jpg
# /content/flowers/test/44/image_01512.jpg
# /content/flowers/test/44/image_01564.jpg
# /content/flowers/test/81/image_00828.jpg
# /content/flowers/test/81/image_00888.jpg
# /content/flowers/test/81/image_00815.jpg
# /content/flowers/test/81/image_00946.jpg
# /content/flowers/test/81/image_00833.jpg
# /content/flowers/test/81/image_00825.jpg
# /content/flowers/test/81/image_00818.jpg
# /content/flowers/test/81/image_00826.jpg
# /content/flowers/test/81/image_00798.jpg
# /content/flowers/test/81/image_00869.jpg
# /content/flowers/test/81/image_00898.jpg
# /content/flowers/test/81/image_00814.jpg
# /content/flowers/test/81/image_00926.jpg
# /content/flowers/test/92/image_03041.jpg
# /content/flowers/test/92/image_03044.jpg
# /content/flowers/test/92/image_03032.jpg
# /content/flowers/test/92/image_03058.jpg
# /content/flowers/test/92/image_03054.jpg
# /content/flowers/test/92/image_03039.jpg
# /content/flowers/test/92/image_03052.jpg
# /content/flowers/test/92/image_03075.jpg
# /content/flowers/test/92/image_03056.jpg
# /content/flowers/test/92/image_03048.jpg
# /content/flowers/test/92/image_03049.jpg
# /content/flowers/test/47/image_04993.jpg
# /content/flowers/test/47/image_05013.jpg
# /content/flowers/test/47/image_04966.jpg
# /content/flowers/test/53/image_03649.jpg
# /content/flowers/test/53/image_03714.jpg
# /content/flowers/test/53/image_03645.jpg
# /content/flowers/test/53/image_03672.jpg
# /content/flowers/test/53/image_03669.jpg
# /content/flowers/test/53/image_03689.jpg
# /content/flowers/test/53/image_03717.jpg
# /content/flowers/test/53/image_03662.jpg
# /content/flowers/test/53/image_03724.jpg
# /content/flowers/test/53/image_03653.jpg
# /content/flowers/test/53/image_03712.jpg
# /content/flowers/test/53/image_03652.jpg
# /content/flowers/test/53/image_03718.jpg
# /content/flowers/test/53/image_03677.jpg
# /content/flowers/test/19/image_06196.jpg
# /content/flowers/test/19/image_06155.jpg
# /content/flowers/test/19/image_06175.jpg
# /content/flowers/test/19/image_06159.jpg
# /content/flowers/test/19/image_06170.jpg
# /content/flowers/test/19/image_06186.jpg
# /content/flowers/test/19/image_06197.jpg
# /content/flowers/test/13/image_05787.jpg
# /content/flowers/test/13/image_05767.jpg
# /content/flowers/test/13/image_05761.jpg
# /content/flowers/test/13/image_05769.jpg
# /content/flowers/test/13/image_05745.jpg
# /content/flowers/test/13/image_05775.jpg
# /content/flowers/test/46/image_00958.jpg
# /content/flowers/test/46/image_01092.jpg
# /content/flowers/test/46/image_00999.jpg
# /content/flowers/test/46/image_01077.jpg
# /content/flowers/test/46/image_01071.jpg
# /content/flowers/test/46/image_01125.jpg
# /content/flowers/test/46/image_01061.jpg
# /content/flowers/test/46/image_00990.jpg
# /content/flowers/test/46/image_01090.jpg
# /content/flowers/test/46/image_01038.jpg
# /content/flowers/test/46/image_01109.jpg
# /content/flowers/test/46/image_01119.jpg
# /content/flowers/test/46/image_00996.jpg
# /content/flowers/test/46/image_01003.jpg
# /content/flowers/test/46/image_00970.jpg
# /content/flowers/test/46/image_01078.jpg
# /content/flowers/test/46/image_00961.jpg
# /content/flowers/test/46/image_01115.jpg
# /content/flowers/test/46/image_00976.jpg
# /content/flowers/test/46/image_01026.jpg
# /content/flowers/test/46/image_00969.jpg
# /content/flowers/test/30/image_03488.jpg
# /content/flowers/test/30/image_03542.jpg
# /content/flowers/test/30/image_03482.jpg
# /content/flowers/test/30/image_03484.jpg
# /content/flowers/test/30/image_03489.jpg
# /content/flowers/test/30/image_03510.jpg
# /content/flowers/test/30/image_03509.jpg
# /content/flowers/test/30/image_03512.jpg
# /content/flowers/test/30/image_03538.jpg
# /content/flowers/test/30/image_03541.jpg
# /content/flowers/test/30/image_03481.jpg
# /content/flowers/test/30/image_03528.jpg
# /content/flowers/test/30/image_03506.jpg
# /content/flowers/test/30/image_03466.jpg
# /content/flowers/test/78/image_01931.jpg
# /content/flowers/test/78/image_01949.jpg
# /content/flowers/test/78/image_01843.jpg
# /content/flowers/test/78/image_01888.jpg
# /content/flowers/test/78/image_01874.jpg
# /content/flowers/test/78/image_01893.jpg
# /content/flowers/test/78/image_01848.jpg
# /content/flowers/test/78/image_01903.jpg
# /content/flowers/test/78/image_01856.jpg
# /content/flowers/test/78/image_01830.jpg
# /content/flowers/test/78/image_01855.jpg
# /content/flowers/test/78/image_01928.jpg
# /content/flowers/test/78/image_01953.jpg
# /content/flowers/test/78/image_01919.jpg
# /content/flowers/test/12/image_04059.jpg
# /content/flowers/test/12/image_04014.jpg
# /content/flowers/test/12/image_04077.jpg
# /content/flowers/test/12/image_04016.jpg
# /content/flowers/test/12/image_04052.jpg
# /content/flowers/test/12/image_04023.jpg
# /content/flowers/test/12/image_03994.jpg
# /content/flowers/test/12/image_04012.jpg
# /content/flowers/test/12/image_03996.jpg
# /content/flowers/test/41/image_02302.jpg
# /content/flowers/test/41/image_02245.jpg
# /content/flowers/test/41/image_02193.jpg
# /content/flowers/test/41/image_02251.jpg
# /content/flowers/test/41/image_02305.jpg
# /content/flowers/test/41/image_02222.jpg
# /content/flowers/test/41/image_02200.jpg
# /content/flowers/test/41/image_02263.jpg
# /content/flowers/test/41/image_02270.jpg
# /content/flowers/test/41/image_02306.jpg
# /content/flowers/test/41/image_02261.jpg
# /content/flowers/test/41/image_02237.jpg
# /content/flowers/test/41/image_02266.jpg
# /content/flowers/test/41/image_02257.jpg
# /content/flowers/test/99/image_07874.jpg
# /content/flowers/test/99/image_07871.jpg
# /content/flowers/test/99/image_07857.jpg
# /content/flowers/test/99/image_07833.jpg
# /content/flowers/test/99/image_07840.jpg
# /content/flowers/test/99/image_07854.jpg
# /content/flowers/test/99/image_07838.jpg
# /content/flowers/test/76/image_02472.jpg
# /content/flowers/test/76/image_02479.jpg
# /content/flowers/test/76/image_02484.jpg
# /content/flowers/test/76/image_02550.jpg

# %%
# creating function for maintaining reproducibility

def manual_seed(random_seed: int = 42) -> None:
    '''
    For maintaining reproducibility of a notebook cell.
    '''
    # for non-cuda
    torch.manual_seed(random_seed)
    # in case cuda exists
    if torch.cuda.is_available():
        torch.cuda.manual_seed(random_seed)

# creating device agnostic code
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# clearing cache if using GPU
if str(device) == "cuda":
    torch.cuda.empty_cache()

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomRotation(15),
        transforms.RandomResizedCrop((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),

    'valid': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),

    'test': transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test']),
}

# TODO: Using the image datasets and the transforms, define the dataloaders
dataloaders = {
    'train': DataLoader(image_datasets['train'], batch_size=64, shuffle=True),
    'valid': DataLoader(image_datasets['valid'], batch_size=64, shuffle=False),
    'test': DataLoader(image_datasets['test'], batch_size=64, shuffle=False)
}

# Now you can access the number of classes
num_classes = len(image_datasets['train'].class_to_idx)

print(f"The dataset has {num_classes} classes.")
# Out:
# The dataset has 102 classes.

# %%
import json

def load_label_mapping(json_file_path):
    """
    Load the label mapping from a JSON file and return a dictionary
    that maps class indices to flower names.

    Args:
    json_file_path (str): Path to the JSON file containing the label mapping.

    Returns:
    dict: A dictionary where keys are class indices (as strings) and values are the corresponding flower names.
    """
    with open(json_file_path, 'r') as f:
        cat_to_name = json.load(f)
    return cat_to_name

def get_flower_name(class_index, label_mapping):
    """
    Convert a class index to its corresponding flower name using the label mapping.

    Args:
    class_index (int): The class index of the flower.
    label_mapping (dict): Dictionary mapping class indices to flower names.

    Returns:
    str: The flower name corresponding to the class index.
    """
    return label_mapping.get(str(class_index), "Unknown class")

# Example usage
json_file_path = 'cat_to_name.json'
label_mapping = load_label_mapping(json_file_path)

# Example class indices to test
example_class_indices = [21, 3, 45]

# Map class indices to flower names
flower_names = [get_flower_name(index, label_mapping) for index in example_class_indices]

print(flower_names)  # Outputs the flower names corresponding to the indices
# Out:
# ['fire lily', 'canterbury bells', 'bolero deep blue']

# %%
import torch

def get_device():
    """
    Check for CUDA availability and return the appropriate device.

    Returns:
    torch.device: The device to be used for computation (either 'cuda' or 'cpu').
    """
    if torch.cuda.is_available():
        device = torch.device('cuda')
        print(f"Using GPU: {torch.cuda.get_device_name(0)}")
    else:
        device = torch.device('cpu')
        print("Using CPU")
    return device

# Example usage
device = get_device()
# Out:
# Using GPU: Tesla T4

# %%
# Define the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Load the pre-trained ResNet50 model with default weights
model = models.resnet50(weights='DEFAULT')

# Modify the final fully connected layer for your specific number of classes
num_classes = 102  # Update this according to your dataset
model.fc = nn.Sequential(
    nn.Linear(in_features=2048, out_features=512),
    nn.ReLU(),
    #nn.Dropout(p=0.5),  # Dropout layer with 50% probability
    nn.Linear(in_features=512, out_features=num_classes)
)

# Move model to the device
model.to(device)

# Define the criterion (loss function)
criterion = nn.CrossEntropyLoss()

# Define the optimizer
# Only parameters of the classifier (not the frozen layers) should be updated
optimizer = optim.Adam(model.fc.parameters(), lr=1e-3)

# Print the model architecture to verify
print(model)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 134MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=102, bias=True)
#   )
# )

# %%
# Define the number of epochs
epochs = 5
steps = 0
print_every = 20

# Training loop
for epoch in range(epochs):
    model.train()   # switching model to training mode
    running_loss = 0
    for inputs, labels in dataloaders['train']:  # Use dataloaders['train']
        steps += 1
        # Move input and label tensors to the default device
        inputs, labels = inputs.to(device), labels.type(torch.long).to(device)

        optimizer.zero_grad()
        # Forward pass
        logits = model(inputs)
        loss = criterion(logits, labels)

        # Backward pass
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        if steps % print_every == 0:
            model.eval()
            test_loss = 0
            accuracy = 0
            # Use dataloaders['test'] here
            for inputs, labels in dataloaders['valid']:  # Use dataloaders['test']
                inputs, labels = inputs.to(device), labels.type(torch.long).to(device)  # Move to device
                with torch.inference_mode():
                    logits = model(inputs)
                loss = criterion(logits, labels)
                test_loss += loss.item()

                # Calculate accuracy
                ps = torch.softmax(logits, dim=-1)
                top_class = ps.argmax(dim=-1)
                equality = top_class == labels.view(*top_class.shape)
                accuracy += torch.mean(equality.type(torch.FloatTensor))

            print(f"Epoch {epoch+1}/{epochs}.."
                  f"Train loss: {running_loss/print_every:.3f}.."
                  f"Validation loss: {test_loss/len(dataloaders['valid']):.3f}.."
                  f"Validation accuracy: {accuracy/len(dataloaders['valid']):.3f}..")
# Out:
# Epoch 1/5..Train loss: 4.338..Validation loss: 3.966..Validation accuracy: 0.214..
# Epoch 1/5..Train loss: 7.863..Validation loss: 3.060..Validation accuracy: 0.373..
# Epoch 1/5..Train loss: 10.623..Validation loss: 2.132..Validation accuracy: 0.565..
# Epoch 1/5..Train loss: 12.604..Validation loss: 1.605..Validation accuracy: 0.661..
# Epoch 1/5..Train loss: 14.125..Validation loss: 1.183..Validation accuracy: 0.787..
# Epoch 2/5..Train loss: 1.096..Validation loss: 0.999..Validation accuracy: 0.767..
# Epoch 2/5..Train loss: 2.141..Validation loss: 0.839..Validation accuracy: 0.829..
# Epoch 2/5..Train loss: 3.062..Validation loss: 0.729..Validation accuracy: 0.846..
# Epoch 2/5..Train loss: 3.898..Validation loss: 0.653..Validation accuracy: 0.849..
# Epoch 2/5..Train loss: 4.666..Validation loss: 0.581..Validation accuracy: 0.873..
# Epoch 3/5..Train loss: 0.482..Validation loss: 0.577..Validation accuracy: 0.863..
# Epoch 3/5..Train loss: 1.168..Validation loss: 0.509..Validation accuracy: 0.889..
# Epoch 3/5..Train loss: 1.771..Validation loss: 0.478..Validation accuracy: 0.894..
# Epoch 3/5..Train loss: 2.363..Validation loss: 0.438..Validation accuracy: 0.909..
# Epoch 3/5..Train loss: 2.924..Validation loss: 0.462..Validation accuracy: 0.892..
# Epoch 4/5..Train loss: 0.294..Validation loss: 0.427..Validation accuracy: 0.901..
# Epoch 4/5..Train loss: 0.777..Validation loss: 0.437..Validation accuracy: 0.888..
# Epoch 4/5..Train loss: 1.266..Validation loss: 0.407..Validation accuracy: 0.898..
# Epoch 4/5..Train loss: 1.723..Validation loss: 0.410..Validation accuracy: 0.908..
# Epoch 4/5..Train loss: 2.177..Validation loss: 0.358..Validation accuracy: 0.918..
# Epoch 5/5..Train loss: 0.137..Validation loss: 0.326..Validation accuracy: 0.922..
# Epoch 5/5..Train loss: 0.530..Validation loss: 0.320..Validation accuracy: 0.918..
# Epoch 5/5..Train loss: 0.910..Validation loss: 0.334..Validation accuracy: 0.922..
# Epoch 5/5..Train loss: 1.299..Validation loss: 0.288..Validation accuracy: 0.934..
# Epoch 5/5..Train loss: 1.696..Validation loss: 0.291..Validation accuracy: 0.933..

# %%
# TODO: Save the checkpoint
# Define the checkpoint dictionary
checkpoint = {
    'epoch': epochs,  # Number of epochs trained
    'model_state_dict': model.state_dict(),  # Model's state dict
    'optimizer_state_dict': optimizer.state_dict(),  # Optimizer's state dict
    'class_to_idx': image_datasets['train'].class_to_idx,  # Mapping from class index to class name
    'input_size': 224,  # Input size used for the model
    'hidden_units': 512,  # Example of hidden units, adjust as necessary
    'learning_rate': 0.001  # Learning rate used
}

# Save the checkpoint
torch.save(checkpoint, 'checkpoint.pth')
print("Checkpoint saved successfully!")

# Load the checkpoint
checkpoint = torch.load('checkpoint.pth')

# Restore the model state
model.load_state_dict(checkpoint['model_state_dict'])

# Restore the optimizer state
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

# Restore other information if needed
epochs = checkpoint['epoch'] # Changed num_epochs to epochs
class_to_idx = checkpoint['class_to_idx']
# Out:
# Checkpoint saved successfully!
# <ipython-input-12-f63474a303a3>:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('checkpoint.pth')

# %%
def load_checkpoint(filepath):
    # Load the checkpoint
    checkpoint = torch.load(filepath)

    # Rebuild the model
    model = models.resnet50(pretrained=True)  # Adjust the model as necessary
    for param in model.parameters():
        param.requires_grad = False  # Freeze the parameters

    # Modify the classifier to match the number of classes in your dataset and the original structure
    num_classes = len(checkpoint['class_to_idx'])  # Get the number of classes from the checkpoint
    model.fc = nn.Sequential(
        nn.Linear(in_features=2048, out_features=512),
        nn.ReLU(),
        nn.Linear(in_features=512, out_features=num_classes)
    )

    # Load the model state
    model.load_state_dict(checkpoint['model_state_dict'])

    # Restore other information if needed
    optimizer = torch.optim.Adam(model.fc.parameters(), lr=checkpoint['learning_rate'])  # Adjust optimizer as necessary
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    return model, optimizer, checkpoint['epoch'], checkpoint['class_to_idx']

# Example usage
model, optimizer, start_epoch, class_to_idx = load_checkpoint('checkpoint.pth')
print("Model and optimizer loaded successfully!")
# Out:
# <ipython-input-13-e287b6421453>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filepath)
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 192MB/s]
# Model and optimizer loaded successfully!

# %%
from PIL import Image

def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # Open the image using Image.open() to get the image object
    # image_path = '/content/flowers/test/100/image_07896.jpg'  # Replace with the actual path to your image
    # image = Image.open(image_path)
    # process_image(image)

    # Verify that the image object is successfully loaded
    print(type(image))  # This should output <class 'PIL.JpegImagePlugin.JpegImageFile'> or similar

    # Define the desired size for the image
    size = 256  # Resize to 256x256
    crop_size = 224  # Crop to 224x224

    # Step 1: Resize the image
    image = image.resize((size, size))
    resized_image = image.resize((256, 256))
    # Save the resized image or display it
    resized_image.save('resized_image.jpg')
    resized_image.show()

    # Step 2: Center crop the image
    left = (size - crop_size) / 2
    top = (size - crop_size) / 2
    right = (size + crop_size) / 2
    bottom = (size + crop_size) / 2
    image = image.crop((left, top, right, bottom))

    # Step 3: Convert the image to a numpy array
    image_array = np.array(image)

    # Step 4: Normalize the image
    # Normalize using the mean and standard deviation for ImageNet
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])

    # Scale the pixel values to [0, 1]
    image_array = image_array / 255.0

    # Normalize the image
    image_array = (image_array - mean) / std

    # Step 5: Rearrange the dimensions to match PyTorch's input format (C, H, W)
    image_array = image_array.transpose((2, 0, 1))  # Change from (H, W, C) to (C, H, W)

    return image_array

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()

    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0)) if not isinstance(image, np.ndarray) else image.transpose((1,2,0))

    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)

    ax.imshow(image)

    return ax

# %%
import torch
from PIL import Image
import torchvision.transforms as transforms

import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model. '''

    # Load the image
    image = Image.open(image_path)

    # Define the transformations (make sure they match the training transformations)
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    # Preprocess the image
    image = preprocess(image)

    # Add a batch dimension
    image = image.unsqueeze(0)  # Shape: [1, C, H, W]

    # Put the model in evaluation mode
    model.eval()

    with torch.no_grad():  # Disable gradient calculation
        output = model(image)  # Forward pass
        probabilities = torch.nn.functional.softmax(output, dim=1)  # Apply softmax to get probabilities

        # Get the top K probabilities and indices
        top_probs, top_indices = torch.topk(probabilities, topk)

        # Convert to numpy arrays and detach from the graph
        top_probs = top_probs.numpy().flatten()
        top_indices = top_indices.numpy().flatten()

    return top_probs, top_indices

#test
#'path/to/your/image.jpg -> change into actual path
#image_path = 'path/to/your/image.jpg'  # Replace with your image path
image_path = '/content/flowers/test/30/image_03538.jpg'  # Replace with your image path
top_probs, top_indices = predict(image_path, model, topk=5)

# creating inverse mapping
idx_to_class = {val: key for (key, val) in image_datasets["train"].class_to_idx.items()}

print("Top 5 Predictions:")
for i in range(len(top_probs)):
    print(f"Flower name: {cat_to_name[idx_to_class[top_indices[i]]]}, Probability: {top_probs[i]}")
# Out:
# Top 5 Predictions:
# Flower name: sweet william, Probability: 0.9969045519828796
# Flower name: barbeton daisy, Probability: 0.0012077295687049627
# Flower name: blanket flower, Probability: 0.0007054658490233123
# Flower name: carnation, Probability: 0.0003234014438930899
# Flower name: primula, Probability: 0.00028992199804633856

# %%
# Correction done: pay attention to this

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

def display_image_with_predictions(image, top_classes, probabilities):
    """Display an image along with the top 5 predicted classes and their probabilities."""

    # Create a figure with two subplots: one for the image and one for the bar graph
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

    # Display the image in the first subplot
    ax1.imshow(image)
    ax1.axis('off')  # Hide the axis

    # Set the title to the top predicted class (the first in the top_classes list)
    top_class_name = top_classes[0]
    ax1.set_title(f'Predicted Flower: {top_class_name}')

    # Create a horizontal bar plot in the second subplot
    y_pos = np.arange(len(top_classes))
    ax2.barh(y_pos, probabilities, align='center')
    ax2.set_yticks(y_pos)
    ax2.set_yticklabels(top_classes)
    ax2.invert_yaxis()  # Invert y-axis so the highest probability is at the top
    ax2.set_xlabel('Probability')
    ax2.set_xlim([0, 1])  # Set x-axis limits between 0 and 1

    # Add title for the bar chart
    ax2.set_title('Top 5 Predictions')

    # Display the plot
    plt.tight_layout()
    plt.show()

# Assuming 'cat_to_name' and 'idx_to_class' are defined elsewhere in your code

# Load an example image (make sure to provide the correct path to your image)
image_path = '/content/flowers/test/100/image_07896.jpg'  # Update this path
image = Image.open(image_path)

# Example top classes and probabilities (assuming you have the top_indices and top_probs)
top_classes = [cat_to_name[idx_to_class[item]] for item in top_indices]

# Display the image along with the top 5 classes
display_image_with_predictions(image, top_classes, top_probs)

# %%
import argparse

# Define the arguments for the script
parser = argparse.ArgumentParser(description="Train a new network on a dataset.")
parser.add_argument('data_dir', type=str, help='Path to dataset directory')
parser.add_argument('--save_dir', type=str, help='Directory to save checkpoint', default='.')
parser.add_argument('--arch', type=str, help='Model architecture (vgg16, resnet50)', default='resnet50')
parser.add_argument('--learning_rate', type=float, help='Learning rate', default=0.001)
parser.add_argument('--hidden_units', type=int, help='Number of hidden units', default=512)
parser.add_argument('--epochs', type=int, help='Number of training epochs', default=20)
parser.add_argument('--gpu', action='store_true', help='Use GPU for training')

# Mock the command line arguments
args = parser.parse_args(['flowers', '--epochs', '20']) # example arguments, modify as needed

# Code to load data, set up model, train, and save the checkpoint

# %%
import argparse

# Define the arguments for the script
parser = argparse.ArgumentParser(description="Train a new network on a dataset.")
parser.add_argument('data_dir', type=str, help='Path to dataset directory')
parser.add_argument('--save_dir', type=str, help='Directory to save checkpoint', default='.')
parser.add_argument('--arch', type=str, help='Model architecture (vgg16, resnet50)', default='resnet50')
parser.add_argument('--learning_rate', type=float, help='Learning rate', default=0.001)
parser.add_argument('--hidden_units', type=int, help='Number of hidden units', default=512)
parser.add_argument('--epochs', type=int, help='Number of training epochs', default=20)
parser.add_argument('--gpu', action='store_true', help='Use GPU for training')
parser.add_argument('--top_k', type=int, default=1, help='Return top K most likely classes')
parser.add_argument('--category_names', type=str, default='cat_to_name.json', help='Path to JSON file mapping categories to names')

# Instead of trying to parse arguments directly, define them as a dictionary
args_dict = {
    'data_dir': 'flowers',  # Example data directory
    'epochs': 20,           # Example number of epochs
    # Add other arguments as needed
}

# Create an object to hold the arguments
args = argparse.Namespace(**args_dict)

# Code to load data, set up model, train, and save the checkpoint
